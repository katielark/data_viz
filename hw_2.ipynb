# %% [markdown]
# HW 2: I worked with Emma Brown and Jocelyn Rosa to complete this assignment!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

import dhs_util
from dhs_util import *

# %%
os.chdir('/Users/katielark/Downloads/data_viz')
df = pd.read_csv('dhs_service_records_synthesized_final.csv')
df = dhs_preprocessing(df)
df, service_map = add_service_label(df)
df = add_age_bin(df)

recipient = get_recipient_attribute(df)

# %%
df
# Out:
#              id       date                                            service  \
# 0          1626 2021-01-31  Children_Attending_Early_Childhood_Programs_Ma...
# 1          1626 2021-02-28  Children_Attending_Early_Childhood_Programs_Ma...
# 2          1626 2021-03-31  Children_Attending_Early_Childhood_Programs_Ma...
# 3          1626 2021-04-30  Children_Attending_Early_Childhood_Programs_Ma...
# 4          1626 2021-05-31  Children_Attending_Early_Childhood_Programs_Ma...
# ...         ...        ...                                                ...
# 7116129  530832 2021-06-30                                           Suicides
# 7116130  532121 2021-04-30                                           Suicides
# 7116131  533991 2021-11-30                                           Suicides
# 7116132  534127 2021-07-31                                           Suicides
# 7116133  535156 2021-06-30                                           Suicides
#
#          age    gender     race              ethnicity  \
# 0          5    1~Male  1~White             99~Unknown
# 1          5    1~Male  1~White             99~Unknown
# 2          5    1~Male  1~White             99~Unknown
# 3          5    1~Male  1~White             99~Unknown
# 4          5    1~Male  1~White             99~Unknown
# ...      ...       ...      ...                    ...
# 7116129   17    1~Male  1~White             99~Unknown
# 7116130   22  2~Female  1~White             99~Unknown
# 7116131   16    1~Male  1~White             99~Unknown
# 7116132   19    1~Male  1~White  2~Not Hispanic/Latinx
# 7116133   24    1~Male  1~White             99~Unknown
#
#                         marital                      education     month serv  \
# 0                    99~Unknown  9-12~High School (grade 9-12)   January  S01
# 1                    99~Unknown  9-12~High School (grade 9-12)  February  S01
# 2                    99~Unknown  9-12~High School (grade 9-12)     March  S01
# 3                    99~Unknown  9-12~High School (grade 9-12)     April  S01
# 4                    99~Unknown  9-12~High School (grade 9-12)       May  S01
# ...                         ...                            ...       ...  ...
# 7116129              99~Unknown                     99~Unknown      June  S22
# 7116130  1~Single-Never Married  9-12~High School (grade 9-12)     April  S22
# 7116131  1~Single-Never Married  9-12~High School (grade 9-12)  November  S22
# 7116132               4~Widowed           GRAD~Graduate Degree      July  S22
# 7116133  1~Single-Never Married  9-12~High School (grade 9-12)      June  S22
#
#         age_bin
# 0           0-9
# 1           0-9
# 2           0-9
# 3           0-9
# 4           0-9
# ...         ...
# 7116129   10-19
# 7116130   20-29
# 7116131   10-19
# 7116132   10-19
# 7116133   20-29
#
# [7116134 rows x 12 columns]

# %%
recipient
# Out:
#              id  num_service  distinct_service first_date  last_date  \
# 0             1           12                 1 2021-01-31 2021-12-31
# 12            2            1                 1 2021-02-28 2021-02-28
# 13            3           11                 1 2021-02-28 2021-12-31
# 24            4            4                 1 2021-03-31 2021-12-31
# 28            5           12                 1 2021-01-31 2021-12-31
# ...         ...          ...               ...        ...        ...
# 7116023  535604           22                 3 2021-01-31 2021-12-31
# 7116045  535605           14                 3 2021-01-31 2021-12-31
# 7116059  535606           21                 3 2021-01-31 2021-12-31
# 7116080  535607           42                 5 2021-01-31 2021-12-31
# 7116122  535608           12                 1 2021-01-31 2021-12-31
#
#          num_month  distinct_month  age    gender                      race  \
# 0               12              12   13    1~Male                99~Unknown
# 12               1               1   70  2~Female                   1~White
# 13              11              11   29  2~Female                   1~White
# 24               4               4    4  2~Female                   1~White
# 28              12              12   40    1~Male  2~Black/African American
# ...            ...             ...  ...       ...                       ...
# 7116023         22              12   27    1~Male                   1~White
# 7116045         14              12   20  2~Female  2~Black/African American
# 7116059         21              11   75  2~Female                   1~White
# 7116080         42              12   48  2~Female  2~Black/African American
# 7116122         12              12    3  2~Female                99~Unknown
#
#                      ethnicity                 marital  \
# 0        2~Not Hispanic/Latinx              99~Unknown
# 12       2~Not Hispanic/Latinx               2~Married
# 13       2~Not Hispanic/Latinx               2~Married
# 24       2~Not Hispanic/Latinx  1~Single-Never Married
# 28       2~Not Hispanic/Latinx               2~Married
# ...                        ...                     ...
# 7116023  2~Not Hispanic/Latinx  1~Single-Never Married
# 7116045  2~Not Hispanic/Latinx  1~Single-Never Married
# 7116059  2~Not Hispanic/Latinx  1~Single-Never Married
# 7116080  2~Not Hispanic/Latinx  1~Single-Never Married
# 7116122             99~Unknown  1~Single-Never Married
#
#                                      education serv age_bin
# 0        GED~High School Diploma/GED Completed  S12   10-19
# 12                                  99~Unknown  S12   70-79
# 13               9-12~High School (grade 9-12)  S12   20-29
# 24               9-12~High School (grade 9-12)  S12     0-9
# 28                      UNDERGRAD~Some College  S12   40-49
# ...                                        ...  ...     ...
# 7116023          9-12~High School (grade 9-12)  S09   20-29
# 7116045          9-12~High School (grade 9-12)  S09   20-29
# 7116059          9-12~High School (grade 9-12)  S09   70-79
# 7116080                 UNDERGRAD~Some College  S06   40-49
# 7116122          9-12~High School (grade 9-12)  S12     0-9
#
# [533799 rows x 15 columns]

# %% [markdown]
# 1. Choose a pair or multiple behavior cohorts of recipients based on a set of behavior criteria that you think may be of importance (to the works done at DHS)
# - e.g., recipients who received mental health service (S14) vs. those who did not
# - e.g., recipients who received mental health service AND income support vs. those who received mental health support only (or the other way around)

# %%
s15_id =df.query("serv == 'S15'")['id'].unique()
len(s15_id)
# Out:
# 12812

# %%
one_serv_id = recipient.query("distinct_service == 1").id.to_list()
len(one_serv_id)
# Out:
# 424468

# %%
s15_only = list(set(s15_id) & set(one_serv_id))
len(s15_only)
# Out:
# 38

# %%
s14_id =df.query("serv == 'S14'")['id'].unique()
len(s14_id)
# Out:
# 55263

# %%
s14_s15 = list(set(s14_id) & set(s15_id))
len(s14_s15)
# Out:
# 5278

# %%
s_15 = list(set(s15_id)-set(s14_s15)-set(s15_only))
len(s_15)
# Out:
# 7496

# %%
cohort1 = pd.DataFrame(zip(s14_s15, ['ch1']*len(s14_s15)),columns=['id','cohort']) #cohort for ids receiving BOTH substance abuse AND mental health services
cohort2 = pd.DataFrame(zip(s_15, ['ch2']*len(s_15)),columns=['id','cohort']) #cohort for ids receiving mental health services (excluding mental health and only 1 service)
cohort3 = pd.DataFrame(zip(s15_only, ['ch3']*len(s15_only)),columns=['id','cohort']) #cohort for ids receiving ONLY substance abuse services
cohort_all=pd.concat([cohort1,cohort2,cohort3],axis=0)

# %%
len(cohort_all) #verifying!
# Out:
# 12812

# %%
cohort_all.groupby('cohort').id.nunique() #verifying!
# Out:
# cohort
# ch1    5278
# ch2    7496
# ch3      38
# Name: id, dtype: int64

# %%
df = df.merge(cohort_all, on=['id'], how='inner') #merging df w cohort to make df w all ids in every cohort

# %%
df
# Out:
#             id       date                                   service  age  \
# 0        13207 2021-02-28                          Children_in_Care   14
# 1        13207 2021-10-31                          Children_in_Care   14
# 2        13207 2021-11-30                          Children_in_Care   14
# 3        13476 2021-01-31                          Children_in_Care   14
# 4        13476 2021-02-28                          Children_in_Care   14
# ...        ...        ...                                       ...  ...
# 384995  535363 2021-10-31  Parents_Receiving_Child_Welfare_Services   37
# 384996  535363 2021-11-30  Parents_Receiving_Child_Welfare_Services   37
# 384997  535363 2021-12-31  Parents_Receiving_Child_Welfare_Services   37
# 384998  173291 2021-02-28                                  Suicides   35
# 384999  265837 2021-03-31                                  Suicides   74
#
#           gender                      race              ethnicity  \
# 0       2~Female                   1~White  2~Not Hispanic/Latinx
# 1       2~Female                   1~White  2~Not Hispanic/Latinx
# 2       2~Female                   1~White  2~Not Hispanic/Latinx
# 3         1~Male                   1~White  2~Not Hispanic/Latinx
# 4         1~Male                   1~White  2~Not Hispanic/Latinx
# ...          ...                       ...                    ...
# 384995    1~Male                   1~White  2~Not Hispanic/Latinx
# 384996    1~Male                   1~White  2~Not Hispanic/Latinx
# 384997    1~Male                   1~White  2~Not Hispanic/Latinx
# 384998  2~Female  2~Black/African American  2~Not Hispanic/Latinx
# 384999  2~Female  2~Black/African American  2~Not Hispanic/Latinx
#
#                        marital                              education  \
# 0       1~Single-Never Married                             99~Unknown
# 1       1~Single-Never Married                             99~Unknown
# 2       1~Single-Never Married                             99~Unknown
# 3                   99~Unknown  GED~High School Diploma/GED Completed
# 4                   99~Unknown  GED~High School Diploma/GED Completed
# ...                        ...                                    ...
# 384995  1~Single-Never Married      1-5~Elementary School (Grade 1-5)
# 384996  1~Single-Never Married      1-5~Elementary School (Grade 1-5)
# 384997  1~Single-Never Married      1-5~Elementary School (Grade 1-5)
# 384998  1~Single-Never Married      1-5~Elementary School (Grade 1-5)
# 384999               4~Widowed          9-12~High School (grade 9-12)
#
#            month serv age_bin cohort
# 0       February  S02   10-19    ch1
# 1        October  S02   10-19    ch1
# 2       November  S02   10-19    ch1
# 3        January  S02   10-19    ch1
# 4       February  S02   10-19    ch1
# ...          ...  ...     ...    ...
# 384995   October  S21   30-39    ch1
# 384996  November  S21   30-39    ch1
# 384997  December  S21   30-39    ch1
# 384998  February  S22   30-39    ch1
# 384999     March  S22   70-79    ch1
#
# [385000 rows x 13 columns]

# %%
df.groupby('cohort').nunique() #verifying!
# Out:
#           id  date  service  age  gender  race  ethnicity  marital  education  \
# cohort
# ch1     5278    12       19   84       3     7          3        7          8
# ch2     7496    12       16   90       3     7          3        7          8
# ch3       38    12        1   24       2     3          3        6          8
#
#         month  serv  age_bin
# cohort
# ch1        12    19       10
# ch2        12    16       10
# ch3        12     1        5

# %% [markdown]
# 2. Prepare the analysis file for cohort analysis on your cohorts

# %% [markdown]
# (see preliminary code where I called the utility function!)

# %% [markdown]
# 3. Produce an analysis to answer questions that you think may be insightful
# - e.g., what are the demographic differences between the cohorts?
# - e.g., are there common services (other than income support) that the cohorts have in common?
# - What are some similarities between the cohorts?

# %% [markdown]
# 1. What are the differences in race between the cohorts?

# %%
df1 = df.groupby(['race','cohort']).agg(
    num_recipient= ('id', 'nunique')
).reset_index()
# Out:
# /var/folders/00/yzv7lrx12xq5_g14dw7m_2180000gn/T/ipykernel_58432/1150087562.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df1 = df.groupby(['race','cohort']).agg(

# %%
df1
# Out:
#                                   race cohort  num_recipient
# 0                              1~White    ch1           3810
# 1                              1~White    ch2           5681
# 2                              1~White    ch3             27
# 3             2~Black/African American    ch1           1337
# 4             2~Black/African American    ch2           1585
# 5             2~Black/African American    ch3              7
# 6                              4~Asian    ch1             65
# 7                              4~Asian    ch2            106
# 8                              4~Asian    ch3              4
# 9   5~Native American/Pacific Islander    ch1              4
# 10  5~Native American/Pacific Islander    ch2              1
# 11  5~Native American/Pacific Islander    ch3              0
# 12                 6~Two or More Races    ch1             10
# 13                 6~Two or More Races    ch2             10
# 14                 6~Two or More Races    ch3              0
# 15                 7~Other Single Race    ch1              2
# 16                 7~Other Single Race    ch2              3
# 17                 7~Other Single Race    ch3              0
# 18                          99~Unknown    ch1             50
# 19                          99~Unknown    ch2            110
# 20                          99~Unknown    ch3              0

# %%
groups = df1.groupby("cohort")
fig, axes = plt.subplots(1, len(groups), sharey=True, figsize=(14,8))

for ax, (cohort, group) in zip(axes, groups):
    # The rename_axis function makes the difference
    group.set_index("race").rename_axis(cohort)["num_recipient"].plot(kind="bar", ax=ax)
    ax.tick_params(axis='both', which='both', length=0)

ax.legend()
fig.subplots_adjust(wspace=0)

# %% [markdown]
# Some observations from the graphs/dataframe created above:
#
# More white people receive S15 and S14/S15 than any other race. This could be due to multiple reasons, and likely these reasons confound each other. There is a higher proportion of white people living in Allegheny county, and also there is a higher proportion of white people receiving DHS services in total in Allegheny county. A proportional analysis of S15 and the demographics of Allegheny county would be interesting to investigate.
#
# There is an almost even number of black recipients in Cohorts 1 and Cohorts 2, whereas there is a higher number of white recipients in Cohort 2 than Cohort 1. This indicates that a higher percentage of white recipients are receiving both mental health services in addition to substance abuse services than black recipients. This pattern, though subtle and less significant, is also seen in the Asian recipients as well.

# %% [markdown]
# 2. What are the differences in gender between the cohorts?

# %%
df2 = df.groupby(['gender','cohort']).agg(
    num_recipient= ('id', 'nunique')
).reset_index()
# Out:
# /var/folders/00/yzv7lrx12xq5_g14dw7m_2180000gn/T/ipykernel_58432/3806145661.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df2 = df.groupby(['gender','cohort']).agg(

# %%
groups = df2.groupby("cohort")
fig, axes = plt.subplots(1, len(groups), sharey=True, figsize=(14,8))

for ax, (cohort, group) in zip(axes, groups):
    # The rename_axis function makes the difference
    group.set_index("gender").rename_axis(cohort)["num_recipient"].plot(kind="bar", ax=ax)
    ax.tick_params(axis='both', which='both', length=0)

ax.legend()
fig.subplots_adjust(wspace=0)

# %% [markdown]
# Some observations from the grpahs above:
#
# There is very little significant difference between men and women within the two cohorts.

# %% [markdown]
# 3. Did the 38 recipients who only used s15 receive care multiple months in a year?

# %%
df38 = df[df['cohort'] == 'ch3']
df38
# Out:
#             id       date                                            service  \
# 293551   28815 2021-01-31  Individuals_Receiving_Substance_Use_Disorder_S...
# 293552   28815 2021-02-28  Individuals_Receiving_Substance_Use_Disorder_S...
# 293553   28815 2021-03-31  Individuals_Receiving_Substance_Use_Disorder_S...
# 293554   28815 2021-04-30  Individuals_Receiving_Substance_Use_Disorder_S...
# 293555   28815 2021-05-31  Individuals_Receiving_Substance_Use_Disorder_S...
# ...        ...        ...                                                ...
# 358129  491481 2021-10-31  Individuals_Receiving_Substance_Use_Disorder_S...
# 358130  491481 2021-11-30  Individuals_Receiving_Substance_Use_Disorder_S...
# 358131  491481 2021-12-31  Individuals_Receiving_Substance_Use_Disorder_S...
# 362281  522759 2021-06-30  Individuals_Receiving_Substance_Use_Disorder_S...
# 363524  532241 2021-10-31  Individuals_Receiving_Substance_Use_Disorder_S...
#
#         age    gender                      race              ethnicity  \
# 293551   30    1~Male  2~Black/African American  2~Not Hispanic/Latinx
# 293552   30    1~Male  2~Black/African American  2~Not Hispanic/Latinx
# 293553   30    1~Male  2~Black/African American  2~Not Hispanic/Latinx
# 293554   30    1~Male  2~Black/African American  2~Not Hispanic/Latinx
# 293555   30    1~Male  2~Black/African American  2~Not Hispanic/Latinx
# ...     ...       ...                       ...                    ...
# 358129   21    1~Male  2~Black/African American             99~Unknown
# 358130   21    1~Male  2~Black/African American             99~Unknown
# 358131   21    1~Male  2~Black/African American             99~Unknown
# 362281   34  2~Female                   1~White             99~Unknown
# 363524   36    1~Male                   1~White             99~Unknown
#
#                        marital                      education     month serv  \
# 293551  1~Single-Never Married                     99~Unknown   January  S15
# 293552  1~Single-Never Married                     99~Unknown  February  S15
# 293553  1~Single-Never Married                     99~Unknown     March  S15
# 293554  1~Single-Never Married                     99~Unknown     April  S15
# 293555  1~Single-Never Married                     99~Unknown       May  S15
# ...                        ...                            ...       ...  ...
# 358129  1~Single-Never Married                     99~Unknown   October  S15
# 358130  1~Single-Never Married                     99~Unknown  November  S15
# 358131  1~Single-Never Married                     99~Unknown  December  S15
# 362281  1~Single-Never Married  9-12~High School (grade 9-12)      June  S15
# 363524  1~Single-Never Married  6-8~Middle School (Grade 6-8)   October  S15
#
#        age_bin cohort
# 293551   30-39    ch3
# 293552   30-39    ch3
# 293553   30-39    ch3
# 293554   30-39    ch3
# 293555   30-39    ch3
# ...        ...    ...
# 358129   20-29    ch3
# 358130   20-29    ch3
# 358131   20-29    ch3
# 362281   30-39    ch3
# 363524   30-39    ch3
#
# [134 rows x 13 columns]

# %%
df38_g = df38.groupby(['id']).agg(
    num_months= ('month', 'nunique')
).reset_index()

# %%
df38_g
# Out:
#         id  num_months
# 0    28815           5
# 1    34844           1
# 2    35318           1
# 3    56064           1
# 4    59639           1
# 5    59970           2
# 6    79735          12
# 7    81142           2
# 8    84148           3
# 9    93632           1
# 10  106929           1
# 11  110189           2
# 12  115668           2
# 13  116594           1
# 14  117471           1
# 15  128863           6
# 16  142079          12
# 17  152217           1
# 18  176393           3
# 19  180150           1
# 20  216322           1
# 21  217674          12
# 22  275400           1
# 23  293812           1
# 24  322690           4
# 25  324041          12
# 26  333615           1
# 27  359938           1
# 28  361224           1
# 29  410979          10
# 30  438690           1
# 31  458074           4
# 32  469354          12
# 33  485440           1
# 34  489436           2
# 35  491481           9
# 36  522759           1
# 37  532241           1

# %%
df38_g['num_months'].mean()
# Out:
# 3.526315789473684

# %% [markdown]
# I am very interested by this cohort. In my knowledge of substance abuse, it is often accompanied by a variety of other conditions that demand different services. I am glad to see that there are only 38 recipients in this data that have only sought out substance abuse services, as that implies that most other people seeking this service are being assisted in other ways. I predicted that a majority of these recipients would only have recieved this service once because if they kept returning, DHS would likely encourage them to seek other services as well. And there are many S15 recipients who only received the service once. However, there are a much higher number of recipients who received it 10-12 times than I anticipated.

# %% [markdown]
# 4. What are the common services that the recipients in cohorts 1 and 2 have in common?

# %%
df1415 = df[df['cohort'] == 'ch1']

# %%
df1415_g = df1415.groupby(['serv']).agg(
    num_recipients= ('id', 'nunique')
).reset_index()
# Out:
# /var/folders/00/yzv7lrx12xq5_g14dw7m_2180000gn/T/ipykernel_58432/604539512.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df1415_g = df1415.groupby(['serv']).agg(

# %%
df1415_g
# Out:
#    serv  num_recipients
# 0   S01               0
# 1   S03              21
# 2   S04               0
# 3   S05               0
# 4   S02               9
# 5   S06             253
# 6   S07             286
# 7   S08               1
# 8   S09            5278
# 9   S10             118
# 10  S11             963
# 11  S12            4987
# 12  S13              85
# 13  S14            5278
# 14  S15            5278
# 15  S16             459
# 16  S17            1058
# 17  S18             947
# 18  S19              99
# 19  S20              40
# 20  S21             614
# 21  S22               2

# %%
df15 = df[df['cohort'] == 'ch2']

# %%
df15_g = df15.groupby(['serv']).agg(
    num_recipients= ('id', 'nunique')
).reset_index()
# Out:
# /var/folders/00/yzv7lrx12xq5_g14dw7m_2180000gn/T/ipykernel_58432/2669286439.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df15_g = df15.groupby(['serv']).agg(

# %%
df15_g
# Out:
#    serv  num_recipients
# 0   S01               0
# 1   S03              16
# 2   S04               5
# 3   S05               0
# 4   S02               2
# 5   S06             242
# 6   S07             155
# 7   S08               2
# 8   S09            5094
# 9   S10              84
# 10  S11             878
# 11  S12            7056
# 12  S13              51
# 13  S14               0
# 14  S15            7496
# 15  S16               0
# 16  S17             618
# 17  S18               0
# 18  S19             176
# 19  S20              57
# 20  S21             628
# 21  S22               0

# %%
sns.lineplot(data=df1415_g, x='serv', y='num_recipients', label='df1415')
sns.lineplot(data=df15_g, x='serv', y='num_recipients', label='df15')
plt.xticks(rotation=90)
plt.legend()
plt.show()
#I used the code from workbook 4 to build this graph, but I used chatgpt to learn how to plot two lines associated with two dataframes on the same plot.

# %% [markdown]
# Alright, some analyses from the graph above:
#
# Aside from the obvious things (df15 having  no S14 and both df1415 and df15 having lots of S15), it is interesting to see that both dataframes show that many recipients also receive S12 (income support- the most common service) and S09 (DHS services- I am definintely confused by that column... aren't these all DHS services?)
#
# Additionally, S17 (Jail population) and S21 (Parents receiving child welfare) make notable appearance.
#
# Notably, neither category has high occurrences of "Overdoses", which makes me think that those are marked entirely separate from substance abuse... and there are fewer of them altogether.
#
# Neither service has high instances of the services relating to children.
#
# What is most important to see from this graph, however, is that most people who seek out services for substance abuse do so in conjunction with other services.
